# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
data=pd.read_csv("/Users/gurumithra.s.s/Desktop/Datascience/Life Expectancy Data.csv")
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
data.shape
# Out:
# (2938, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
data.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
x=data['Life expectancy '].mean()
data['Life expectancy '].fillna(x,inplace=True)

x=data['Adult Mortality'].mean()
data['Adult Mortality'].fillna(x,inplace=True)

x=data['Alcohol'].mean()
data['Alcohol'].fillna(x,inplace=True)

x=data['Hepatitis B'].mean()
data['Hepatitis B'].fillna(x,inplace=True)

x=data[' BMI '].mean()
data[' BMI '].fillna(x,inplace=True)

x=data['Polio'].mean()
data['Polio'].fillna(x,inplace=True)

x=data['Total expenditure'].mean()
data['Total expenditure'].fillna(x,inplace=True)

x=data['Diphtheria '].mean()
data['Diphtheria '].fillna(x,inplace=True)

x=data['GDP'].mean()
data['GDP'].fillna(x,inplace=True)

x=data['Population'].mean()
data['Population'].fillna(x,inplace=True)

x=data[' thinness  1-19 years'].mean()
data[' thinness  1-19 years'].fillna(x,inplace=True)

x=data[' thinness 5-9 years'].mean()
data[' thinness 5-9 years'].fillna(x,inplace=True)

x=data['Income composition of resources'].mean()
data['Income composition of resources'].fillna(x,inplace=True)

x=data['Schooling'].mean()
data['Schooling'].fillna(x,inplace=True)
# Out:
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Life expectancy '].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Adult Mortality'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Alcohol'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Hepatitis B'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[' BMI '].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Polio'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Total expenditure'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Diphtheria '].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['GDP'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Population'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[' thinness  1-19 years'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:35: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[' thinness 5-9 years'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Income composition of resources'].fillna(x,inplace=True)
# /var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/ipykernel_4287/3179414679.py:41: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Schooling'].fillna(x,inplace=True)

# %%
data['Country'].value_counts()
# Out:
# Country
# Afghanistan              16
# Peru                     16
# Nicaragua                16
# Niger                    16
# Nigeria                  16
#                          ..
# Niue                      1
# San Marino                1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: count, Length: 193, dtype: int64

# %%
data['Status'].value_counts()
# Out:
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Country']=le.fit_transform(data['Country'])
data['Status']=le.fit_transform(data['Status'])

# %%
data['Country']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 2933    192
# 2934    192
# 2935    192
# 2936    192
# 2937    192
# Name: Country, Length: 2938, dtype: int64

# %%
data.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
x=data.drop('Life expectancy ',axis=1)
y=data['Life expectancy ']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
regressor=DecisionTreeRegressor(max_depth=15,min_samples_split=20)

# %%
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=15, min_samples_split=20)

# %%
y_pred=regressor.predict(x_test)

# %%
print(y_test.shape)
print(y_pred.shape)
# Out:
# (882,)
# (882,)

# %%
finalData_1=pd.DataFrame(['Actual':y_test,'Predicted':y_pred])
finalData_1=pd.finalData_1.round(['Actual':1,'Predicted':1])
# Out:
#   Cell In[18], line 1
#     finalData_1=pd.DataFrame(['Actual':y_test,'Predicted':y_pred])
#                                       ^
# SyntaxError: invalid syntax

# %%
finalData_1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 finalData_1.head()
#
# NameError: name 'finalData_1' is not defined

# %%
n=len(y_test)
mse=y_test-y_pred
mse=mse**2
mse=np.sum(mse)
mse=mse/n
print('Mean Squared Error:',mse)
# Out:
# Mean Squared Error: 6.732090039793633

# %%
# %pip install pickled
# Out:
# Collecting pickled
#   Downloading pickled-2020.5.0a1-py3-none-any.whl.metadata (1.2 kB)
# Collecting napalm (from pickled)
#   Downloading napalm-5.1.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting salt-sproxy (from pickled)
#   Downloading salt_sproxy-2023.8.0-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting setuptools>=38.4.0 (from napalm->pickled)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting cffi>=1.11.3 (from napalm->pickled)
#   Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting paramiko>=2.6.0 (from napalm->pickled)
#   Downloading paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting requests>=2.7.0 (from napalm->pickled)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting textfsm (from napalm->pickled)
#   Downloading textfsm-2.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting jinja2 (from napalm->pickled)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting netaddr (from napalm->pickled)
#   Downloading netaddr-1.3.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting pyYAML (from napalm->pickled)
#   Downloading pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting pyeapi>=1.0.2 (from napalm->pickled)
#   Downloading pyeapi-1.0.4.tar.gz (151 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting netmiko>=4.4.0 (from napalm->pickled)
#   Downloading netmiko-4.6.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting junos-eznc>=2.7.4 (from napalm->pickled)
#   Downloading junos_eznc-2.7.5-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting lxml>=4.3.0 (from napalm->pickled)
#   Downloading lxml-6.0.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Collecting ncclient (from napalm->pickled)
#   Downloading ncclient-0.7.0.tar.gz (116 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ttp (from napalm->pickled)
#   Downloading ttp-0.9.5-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting ttp_templates (from napalm->pickled)
#   Downloading ttp_templates-0.3.7-py3-none-any.whl.metadata (12 kB)
# Collecting netutils>=1.0.0 (from napalm->pickled)
#   Downloading netutils-1.15.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting typing-extensions>=4.3.0 (from napalm->pickled)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pycparser (from cffi>=1.11.3->napalm->pickled)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting scp>=0.7.0 (from junos-eznc>=2.7.4->napalm->pickled)
#   Downloading scp-0.15.0-py2.py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from junos-eznc>=2.7.4->napalm->pickled) (1.17.0)
# Collecting pyserial (from junos-eznc>=2.7.4->napalm->pickled)
#   Downloading pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting yamlordereddictloader (from junos-eznc>=2.7.4->napalm->pickled)
#   Downloading yamlordereddictloader-0.4.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pyparsing in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from junos-eznc>=2.7.4->napalm->pickled) (3.2.3)
# Collecting transitions (from junos-eznc>=2.7.4->napalm->pickled)
#   Downloading transitions-0.9.3-py2.py3-none-any.whl.metadata (97 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->napalm->pickled)
#   Downloading markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting ntc-templates>=3.1.0 (from netmiko>=4.4.0->napalm->pickled)
#   Downloading ntc_templates-8.1.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting rich>=13.8 (from netmiko>=4.4.0->napalm->pickled)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting ruamel.yaml>=0.17 (from netmiko>=4.4.0->napalm->pickled)
#   Downloading ruamel.yaml-0.18.15-py3-none-any.whl.metadata (25 kB)
# Collecting bcrypt>=3.2 (from paramiko>=2.6.0->napalm->pickled)
#   Downloading bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Collecting cryptography>=3.3 (from paramiko>=2.6.0->napalm->pickled)
#   Downloading cryptography-46.0.2-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting invoke>=2.0 (from paramiko>=2.6.0->napalm->pickled)
#   Downloading invoke-2.2.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pynacl>=1.5 (from paramiko>=2.6.0->napalm->pickled)
#   Downloading pynacl-1.6.0-cp38-abi3-macosx_10_10_universal2.whl.metadata (9.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.7.0->napalm->pickled)
#   Downloading charset_normalizer-3.4.3-cp313-cp313-macosx_10_13_universal2.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.7.0->napalm->pickled)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.7.0->napalm->pickled)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.7.0->napalm->pickled)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8->netmiko>=4.4.0->napalm->pickled)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/gurumithra.s.s/Library/Python/3.13/lib/python/site-packages (from rich>=13.8->netmiko>=4.4.0->napalm->pickled) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8->netmiko>=4.4.0->napalm->pickled)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17->netmiko>=4.4.0->napalm->pickled)
#   Downloading ruamel.yaml.clib-0.2.14-cp313-cp313-macosx_15_0_arm64.whl.metadata (3.0 kB)
# Collecting salt (from salt-sproxy->pickled)
#   Downloading salt-3007.8.tar.gz (19.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 1.7 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [36 lines of output]
#       <string>:57: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#       <string>:1231: UserWarning: Warning: distutils is deprecated and shall be removed in Python 3.12, advise migrate to using setuptools
#       <string>:1234: UserWarning: In Salt 3009, the `setup.py` file will be stripped of it's custom additions and migrated to a plain `pyproject.toml` python package or whatever is found best during the process of removing the customizations. If you're relying on these customizations please stop as your workflow will break in the future.
#       Traceback (most recent call last):
#         File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/private/var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/pip-build-env-ygpx3qec/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 331, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/pip-build-env-ygpx3qec/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "/private/var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/pip-build-env-ygpx3qec/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 512, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/pip-build-env-ygpx3qec/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 1239, in <module>
#         File "/private/var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/pip-build-env-ygpx3qec/overlay/lib/python3.13/site-packages/setuptools/__init__.py", line 115, in setup
#           return distutils.core.setup(**attrs)
#                  ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#         File "/private/var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/pip-build-env-ygpx3qec/overlay/lib/python3.13/site-packages/setuptools/_distutils/core.py", line 148, in setup
#           _setup_distribution = dist = klass(attrs)
#                                        ~~~~~^^^^^^^
#         File "<string>", line 906, in __init__
#         File "<string>", line 912, in update_metadata
#         File "<string>", line 1028, in _property_install_requires
#         File "<string>", line 184, in _parse_requirements_file
#       FileNotFoundError: [Errno 2] No such file or directory: '/private/var/folders/db/yn4qb7kj543bshj44ch8hx180000gn/T/pip-install-ka9pqaho/salt_fc5489da03064273a7cf66a347e7b880/requirements/static/pkg/py3.13/darwin.txt'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#